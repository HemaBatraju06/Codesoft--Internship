# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaBatraju06/Codesoft--Internship/blob/main/Day1_45_python_basics_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                         Built calculater

# %%
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
print("Addition:",num1+num2)
print("Subtraction:",num1-num2)
print("Multiplication:",num1*num2)
print("Division:",num1/num2)

# %% [markdown]
#               Built Age finder

# %%
birth_year=int(input("Enter your year of birth:"))
current_year=2026
Age=current_year-birth_year
print(" your age is:",Age)

# %% [markdown]
#                       Built a unit converter

# %%
kilometer=float(input("Enter a kilometer:"))
meter=kilometer*1000
print("Meter:",meter)
